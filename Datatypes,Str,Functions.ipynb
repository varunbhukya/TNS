# %% [markdown]
# <a href="https://colab.research.google.com/github/varunbhukya/TNS/blob/main/Datatypes%2CStr%2CFunctions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
fruits = ["Apple", "Banana", "Mango"]

print(fruits)
print(fruits[0])  # Access first element

# %%
 stud = ['nikhitha','kiran','madhu']
 print(stud)
 print(type(stud))
 stud.append("shila")
 print(stud)
 stud.insert(1,'naresh')
 print(stud)
 stud.remove('madhu')
 print(stud)
 stud.pop(0)
 print(stud)
 stud.sort()
 print(stud)
 stud.reverse()
 print(stud)
 l = len(stud)
 print(l)
 fruit = "Banana"
 fruit.count('a')
# Out:
# ['nikhitha', 'kiran', 'madhu']
# <class 'list'>
# ['nikhitha', 'kiran', 'madhu', 'shila']
# ['nikhitha', 'naresh', 'kiran', 'madhu', 'shila']
# ['nikhitha', 'naresh', 'kiran', 'shila']
# ['naresh', 'kiran', 'shila']
# ['kiran', 'naresh', 'shila']
# ['shila', 'naresh', 'kiran']
# 3
# 3

# %%
colors = ("Red", "Green", "Blue")

print(colors)
print(colors[1])
# Out:
# ('Red', 'Green', 'Blue')
# Green

# %%
car_brands = ('benz','Thar','suzuki','Audi','Thar')
print(car_brands)
print(len(car_brands))
print(car_brands.count('Thar'))
print(car_brands[2])
# Out:
# ('benz', 'Thar', 'suzuki', 'Audi', 'Thar')
# 5
# 2
# suzuki

# %%
numbers = {1, 2, 3, 4}

print(numbers)
# Out:
# {1, 2, 3, 4}

# %%
name1 = {'srija','shiva','teja','priya','Ajith'}
name2 = {'teja','priya','Ajith','kiran','ashok'}
print(name1)
print(name2)
name1.add('task')
print(name1)
name1.remove('srija')
print(name1)
unions = name1.union(name2)
print(unions)
inter = name1.intersection(name2)
print(inter)
dif = name1.difference(name2)
print(dif)
name1.clear()
print(name1)
# Out:
# {'teja', 'shiva', 'priya', 'srija', 'Ajith'}
# {'teja', 'priya', 'kiran', 'ashok', 'Ajith'}
# {'teja', 'shiva', 'task', 'priya', 'srija', 'Ajith'}
# {'teja', 'shiva', 'task', 'priya', 'Ajith'}
# {'shiva', 'ashok', 'teja', 'task', 'priya', 'kiran', 'Ajith'}
# {'priya', 'teja', 'Ajith'}
# {'shiva', 'task'}
# set()

# %%
student = {
    "name": "John",
    "age": 21,
    "course": "AIML"
}
print(student)
print(student.keys())
print(student.values())
print(student.items())
print(student.get('name'))
student.pop('name')
print(student)
student.update({'name':'hello'})
print(student)
student.update({'age':23})
print(student)
# Out:
# {'name': 'John', 'age': 21, 'course': 'AIML'}
# dict_keys(['name', 'age', 'course'])
# dict_values(['John', 21, 'AIML'])
# dict_items([('name', 'John'), ('age', 21), ('course', 'AIML')])
# John
# {'age': 21, 'course': 'AIML'}
# {'age': 21, 'course': 'AIML', 'name': 'hello'}
# {'age': 23, 'course': 'AIML', 'name': 'hello'}

# %%
s = 'python programming'
print(s)
print(len(s))
print(s.upper())
print(s.lower())
print(s.capitalize())
print(s.title())
print(s.replace('python','java'))
print(s.split())
print(s.find('programming'))
print(s.count('o'))
print(s.startswith("Python"))
print(s.endswith("programming"))
'''s1 = '  python  '
#print(s1)

#print(len(s1))
#print(s1.strip())
#print(s1) '''
# Out:
# python programming
# 18
# PYTHON PROGRAMMING
# python programming
# Python programming
# Python Programming
# java programming
# ['python', 'programming']
# 7
# 2
# False
# True
# "s1 = '  python  '\n#print(s1)\n\n#print(len(s1))\n#print(s1.strip())\n#print(s1) "

# %%
def function_name():
    # Function body
    print("Hello World")

function_name()
# Out:
# Hello World

# %%
def display():
    print("Learning Python Functions")

display()

# %%
def greet(name):
    print("Hello", name)

greet("Nikhitha")
greet("Rahul")
# Out:
# Hello Nikhitha
# Hello Rahul

# %%
def add(a, b):
    return a + b

result = add(10, 20)
print(result)
# Out:
# 30

# %%
def square(num):
    return num * num

result = square(5)
print(result)
# Out:
# 25

# %%
#lambda function
add = lambda a, b: a + b
print(add(2, 3))
# Out:
# 5

# %%
n = lambda : 'rahul'
print(n())
# Out:
# <function <lambda> at 0x79ebd2f1e020>

# %%
def function_name(n):
    if condition:        # Base case
        return result
    else:
        return function_name(smaller_input)   # Recursive call

# %%
#recursive
def factorial(n):
    if n == 1:          # Base case
        return 1
    return n * factorial(n-1)

print(factorial(5))

# %%
class Person:
   name = "Kartik"

p = Person()
q = Person()
print(p.name)
print (q.name)

# %%
class Emp :
  eid = 101
  ename = 'Karthik'

obj = Emp()
print('the employee id is :',obj.eid,'and the emp name is :',obj.ename)
# Out:
# the employee id is : 101 and the emp name is : Karthik

# %%
class student:

  def __init__(self,name,age):
    self.name = name
    self.age = age
s1 = student("Nikhitha",34)

print("Name :",s1.name)
print("Age :",s1.age)
# Out:
# Name : Nikhitha
# Age : 34

# %%
class student:
  def __init__(self,name):
    self.name = name

  def display(self):
    print("name of the student: ",self.name)

s1 = student("Nikhitha")
s1.display()
# Out:
# name of the student:  Nikhitha

# %%
class Dog:
    species = "Canine"  # Class attribute

    def __init__(self, name, age):
        self.name = name
        self.age = age

    def dog_name(self, dog, cat):
        self.dog = dog
        self.cat = cat
        print("Dog name:", self.dog)
        print("Cat name:", self.cat)


# Taking input from user
name = input("Enter dog object name: ")
age = int(input("Enter age: "))

dog_value = input("Enter dog name: ")
cat_value = input("Enter cat name: ")

# Creating object
d = Dog(name, age)

# Calling function with user input
d.dog_name(dog_value, cat_value)
# Out:
# Enter dog object name: dog
# Enter age: 23
# Enter dog name: asjhdf
# Enter cat name: dskg
# Dog name: asjhdf
# Cat name: dskg

# %%
class Car:

    price = 500000

    def show(self,color,brand):
        self.color= color
        self.brand = brand
        print(f"The {self.color} color of {self.brand} is wonderful")

c = Car()
car_color = "Blue"
brand_name = "Toyota"
c.show (car_color,brand_name)
print (c.price)
# Out:
# The Blue color of Toyota is wonderful
# 500000
