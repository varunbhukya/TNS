# %% [markdown]
# <a href="https://colab.research.google.com/github/varunbhukya/TNS/blob/main/Q_learning_alg.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Q-Learning learns the best action using a Q-table.
#
# Formula
#
# Q(s,a)=Q(s,a)+α[r+γmax(Q)−Q(s,a)]
#
# Where
#
# α = Learning rate
#
# γ = Discount factor

# %%
import numpy as np

Q = np.zeros((5,2))

learning_rate = 0.8

gamma = 0.95

episodes = 100

for episode in range(episodes):

    state = np.random.randint(0,5)

    action = np.random.randint(0,2)

    reward = np.random.randint(0,10)

    next_state = np.random.randint(0,5)

    Q[state,action] = Q[state,action] + learning_rate * (
        reward + gamma*np.max(Q[next_state]) - Q[state,action]
    )

print("Q Table")

print(Q)
# Out:
# Q Table
# [[50.47666616 53.43494289]
#  [51.53259311 51.20996095]
#  [56.09220915 50.21113836]
#  [50.97417178 48.97976515]
#  [52.75794626 55.68191123]]
